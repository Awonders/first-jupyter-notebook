# %% [markdown]
# #  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: **Ariel W.**
#
#
# Current Occupation: Digital Marketer

# %% [markdown]
# *I am interested in data science because I would like to enter healthcare data science to help improve the services provides and the overall health of the public, especially within underserved communities.*

# %% [markdown]
# ### The 5th cell presents a simple math equation. The answer is presented directly below.

# %%
 1+1
# Out:
# 2

# %% [markdown]
# This cell must include at least 3 of the following:
#
# ---
#
# * horizontal rule
# * bulleted list
# * numbered list
# * tables
# * [hyperlink](https://github.com/Awonders)
# * images
# * code/syntax highlighting
# * blocked quotes
# * ~~strikethrough.~~

# %% [markdown]
# In the cell above I used, horizontal rule, a bulleted list, a hyperlink, and the strikethrough function.
